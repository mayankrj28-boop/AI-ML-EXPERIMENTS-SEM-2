# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data4.csv")
print("Shape:", df.shape)

print("\nFirst 5 Rows:")
print(df.head())

print("\nInfo:")
df.info()

print("\nMissing Values:")
print(df.isnull().sum())

print("\nStatistical Summary:")
print(df.describe())

df.hist()
plt.show()

df.plot(kind='box')
plt.show()

corr = df.corr(numeric_only=True)
print("\nCorrelation Matrix:")
print(corr)

num_cols = df.select_dtypes(include='number').columns

if len(num_cols) >= 2:
    plt.scatter(df[num_cols[0]], df[num_cols[1]])
    plt.xlabel(num_cols[0])
    plt.ylabel(num_cols[1])
    plt.title("Scatter Plot")
    plt.show()
# Out:
# Shape: (15, 4)
#
# First 5 Rows:
#     Name  Age  Marks  Attendance
# 0   Aman   20   85.0        90.0
# 1   Riya   21   78.0        85.0
# 2  Rahul   19    NaN        80.0
# 3  Sneha   22   88.0         NaN
# 4  Karan   20   76.0        88.0
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        15 non-null     object
#  1   Age         15 non-null     int64
#  2   Marks       13 non-null     float64
#  3   Attendance  13 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 612.0+ bytes
#
# Missing Values:
# Name          0
# Age           0
# Marks         2
# Attendance    2
# dtype: int64
#
# Statistical Summary:
#              Age      Marks  Attendance
# count  15.000000  13.000000   13.000000
# mean   21.266667  80.846154   86.461538
# std     1.387015   7.346724    6.424113
# min    19.000000  68.000000   75.000000
# 25%    20.000000  76.000000   83.000000
# 50%    21.000000  80.000000   87.000000
# 75%    22.000000  88.000000   91.000000
# max    24.000000  91.000000   96.000000
# Correlation Matrix:
#                  Age     Marks  Attendance
# Age         1.000000  0.143524    0.119285
# Marks       0.143524  1.000000    0.949210
# Attendance  0.119285  0.949210    1.000000
