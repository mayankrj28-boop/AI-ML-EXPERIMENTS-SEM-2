# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load dataset
df = pd.read_csv("data8.csv")

print("Original Dataset:")
print(df.head())
# SELECT NUMERIC COLUMNS
num_df = df.select_dtypes(include='number')

# HANDLE MISSING VALUES (IMPORTANT)

num_df = num_df.fillna(num_df.mean())

# STANDARDIZE DATA (Z-SCORE)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(num_df)
# APPLY PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)

# Convert to DataFrame
pca_df = pd.DataFrame(data=pca_data, columns=['PC1', 'PC2'])

print("\nPCA Result:")
print(pca_df.head())

# VARIANCE EXPLAINED

print("\nExplained Variance Ratio:")
print(pca.explained_variance_ratio_)

# GRAPH (VERY IMPORTANT)
plt.scatter(pca_df['PC1'], pca_df['PC2'])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Scatter Plot")
plt.show()
# Out:
# Original Dataset:
#    Age  Weight  Height  Steps_Per_Day  Calories_Intake  Heart_Rate
# 0   18      55     165           8000             2200          72
# 1   22      68     170           6000             2500          78
# 2   25      75     175           5000             2700          82
# 3   30      80     178           4000             3000          85
# 4   35      85     180           3500             3200          88
#
# PCA Result:
#         PC1       PC2
# 0 -5.084816  0.230218
# 1 -2.791573 -0.309445
# 2 -1.265090 -0.525218
# 3  0.155330 -0.515324
# 4  1.276345 -0.304990
#
# Explained Variance Ratio:
# [0.97351728 0.01775989]
